# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime
from citipy import citipy

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 768

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retreival     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retreival
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | nikolskoye
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | gondar
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | balboa
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | souillac
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | aklavik
# Processing Record 19 of Set 1 | kruisfontein
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | mikhaylovka
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | ati
# Processing Record 25 of Set 1 | sitka
# Processing Record 26 of Set 1 | saint george
# Processing Record 27 of Set 1 | fortuna
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | peniche
# Processing Record 31 of Set 1 | hachinohe
# Processing Record 32 of Set 1 | ahipara
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | tiksi
# Processing Record 35 of Set 1 | vila
# Processing Record 36 of Set 1 | ha giang
# Processing Record 37 of Set 1 | naryan-mar
# Processing Record 38 of Set 1 | grindavik
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | agropoli
# Processing Record 41 of Set 1 | buraydah
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | bijar
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | chernyshevskiy
# Processing Record 47 of Set 1 | torbay
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | morehead
# Processing Record 50 of Set 1 | skiros
# City not found. Skipping...
# Processing Record 1 of Set 2 | port blair
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 4 of Set 2 | awbari
# Processing Record 5 of Set 2 | devils lake
# Processing Record 6 of Set 2 | kavaratti
# Processing Record 7 of Set 2 | alofi
# Processing Record 8 of Set 2 | anadyr
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | oussouye
# Processing Record 11 of Set 2 | hrubieszow
# Processing Record 12 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 2 | ostrovnoy
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | thompson
# Processing Record 16 of Set 2 | clyde river
# Processing Record 17 of Set 2 | hasaki
# Processing Record 18 of Set 2 | luohe
# Processing Record 19 of Set 2 | terrace bay
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | hermanus
# Processing Record 22 of Set 2 | tuktoyaktuk
# Processing Record 23 of Set 2 | maniitsoq
# Processing Record 24 of Set 2 | abha
# Processing Record 25 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | esmeralda
# Processing Record 28 of Set 2 | vila franca do campo
# Processing Record 29 of Set 2 | qaqortoq
# Processing Record 30 of Set 2 | vila velha
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | salalah
# Processing Record 33 of Set 2 | alyangula
# Processing Record 34 of Set 2 | beatrice
# Processing Record 35 of Set 2 | beringovskiy
# Processing Record 36 of Set 2 | katsuura
# Processing Record 37 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 2 | saskylakh
# Processing Record 39 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 40 of Set 2 | lorengau
# Processing Record 41 of Set 2 | victoria
# Processing Record 42 of Set 2 | tuatapere
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | ipoti
# Processing Record 45 of Set 2 | albany
# Processing Record 46 of Set 2 | westport
# Processing Record 47 of Set 2 | broome
# Processing Record 48 of Set 2 | abonnema
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | lavrentiya
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | bandarbeyla
# Processing Record 3 of Set 3 | port elizabeth
# Processing Record 4 of Set 3 | bambous virieux
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | katherine
# Processing Record 7 of Set 3 | davila
# Processing Record 8 of Set 3 | castro
# Processing Record 9 of Set 3 | neryungri
# Processing Record 10 of Set 3 | vallenar
# Processing Record 11 of Set 3 | athabasca
# Processing Record 12 of Set 3 | ilulissat
# Processing Record 13 of Set 3 | hovd
# Processing Record 14 of Set 3 | karasjok
# Processing Record 15 of Set 3 | constitucion
# Processing Record 16 of Set 3 | gazli
# Processing Record 17 of Set 3 | lagoa
# Processing Record 18 of Set 3 | saldanha
# Processing Record 19 of Set 3 | charters towers
# Processing Record 20 of Set 3 | lingyuan
# Processing Record 21 of Set 3 | atar
# Processing Record 22 of Set 3 | bowen
# Processing Record 23 of Set 3 | capreol
# Processing Record 24 of Set 3 | siyabuswa
# Processing Record 25 of Set 3 | ambovombe
# Processing Record 26 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | riyadh
# Processing Record 29 of Set 3 | kot samaba
# Processing Record 30 of Set 3 | nizwa
# Processing Record 31 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 3 | derzhavinsk
# Processing Record 34 of Set 3 | ancud
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | cherskiy
# Processing Record 37 of Set 3 | atuona
# Processing Record 38 of Set 3 | talnakh
# Processing Record 39 of Set 3 | matagami
# Processing Record 40 of Set 3 | nanortalik
# Processing Record 41 of Set 3 | tolbazy
# Processing Record 42 of Set 3 | lompoc
# Processing Record 43 of Set 3 | kedrovyy
# Processing Record 44 of Set 3 | severo-kurilsk
# Processing Record 45 of Set 3 | chifeng
# Processing Record 46 of Set 3 | kavieng
# Processing Record 47 of Set 3 | cape town
# Processing Record 48 of Set 3 | padang
# Processing Record 49 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 3 | wattegama
# Processing Record 1 of Set 4 | harper
# Processing Record 2 of Set 4 | cravo norte
# Processing Record 3 of Set 4 | joao pinheiro
# Processing Record 4 of Set 4 | keti bandar
# Processing Record 5 of Set 4 | gaoual
# Processing Record 6 of Set 4 | liloy
# Processing Record 7 of Set 4 | narsaq
# Processing Record 8 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 9 of Set 4 | mozarlandia
# Processing Record 10 of Set 4 | vytegra
# Processing Record 11 of Set 4 | elbistan
# Processing Record 12 of Set 4 | east london
# Processing Record 13 of Set 4 | hami
# Processing Record 14 of Set 4 | adrar
# Processing Record 15 of Set 4 | kachikau
# City not found. Skipping...
# Processing Record 16 of Set 4 | juybar
# Processing Record 17 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 4 | asau
# Processing Record 19 of Set 4 | mosquera
# Processing Record 20 of Set 4 | san cristobal
# Processing Record 21 of Set 4 | port keats
# Processing Record 22 of Set 4 | ucluelet
# Processing Record 23 of Set 4 | lecce
# Processing Record 24 of Set 4 | felanitx
# Processing Record 25 of Set 4 | madang
# Processing Record 26 of Set 4 | avera
# Processing Record 27 of Set 4 | inirida
# Processing Record 28 of Set 4 | cookeville
# Processing Record 29 of Set 4 | astipalaia
# City not found. Skipping...
# Processing Record 30 of Set 4 | laguna
# Processing Record 31 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 4 | isabela
# Processing Record 33 of Set 4 | kangalassy
# Processing Record 34 of Set 4 | harda
# Processing Record 35 of Set 4 | yurty
# Processing Record 36 of Set 4 | saint-philippe
# Processing Record 37 of Set 4 | mana
# Processing Record 38 of Set 4 | willmar
# Processing Record 39 of Set 4 | svetlogorsk
# Processing Record 40 of Set 4 | kwinana
# Processing Record 41 of Set 4 | east wenatchee
# Processing Record 42 of Set 4 | urumqi
# Processing Record 43 of Set 4 | bosobolo
# Processing Record 44 of Set 4 | kolpashevo
# Processing Record 45 of Set 4 | zachagansk
# City not found. Skipping...
# Processing Record 46 of Set 4 | high level
# Processing Record 47 of Set 4 | ust-nera
# Processing Record 48 of Set 4 | baykit
# Processing Record 49 of Set 4 | provideniya
# Processing Record 50 of Set 4 | chuy
# Processing Record 1 of Set 5 | acapulco
# Processing Record 2 of Set 5 | pevek
# Processing Record 3 of Set 5 | gravdal
# Processing Record 4 of Set 5 | rodrigues alves
# Processing Record 5 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 5 | spornoye
# Processing Record 7 of Set 5 | zacualpan
# Processing Record 8 of Set 5 | coihaique
# Processing Record 9 of Set 5 | ondjiva
# Processing Record 10 of Set 5 | chandia
# Processing Record 11 of Set 5 | mayna
# Processing Record 12 of Set 5 | cabedelo
# Processing Record 13 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 5 | levelland
# Processing Record 15 of Set 5 | yulara
# Processing Record 16 of Set 5 | kahului
# Processing Record 17 of Set 5 | geraldton
# Processing Record 18 of Set 5 | along
# Processing Record 19 of Set 5 | kaitangata
# Processing Record 20 of Set 5 | bure
# Processing Record 21 of Set 5 | dunedin
# Processing Record 22 of Set 5 | zhigansk
# Processing Record 23 of Set 5 | caravelas
# Processing Record 24 of Set 5 | la seyne-sur-mer
# Processing Record 25 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 27 of Set 5 | batagay
# Processing Record 28 of Set 5 | xuddur
# Processing Record 29 of Set 5 | hajdusamson
# Processing Record 30 of Set 5 | bella union
# Processing Record 31 of Set 5 | bardiyah
# Processing Record 32 of Set 5 | kamaishi
# Processing Record 33 of Set 5 | cururupu
# Processing Record 34 of Set 5 | neiafu
# Processing Record 35 of Set 5 | half moon bay
# Processing Record 36 of Set 5 | iroquois falls
# Processing Record 37 of Set 5 | lata
# Processing Record 38 of Set 5 | oistins
# Processing Record 39 of Set 5 | tura
# Processing Record 40 of Set 5 | cabo san lucas
# Processing Record 41 of Set 5 | maceio
# Processing Record 42 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 5 | esperance
# Processing Record 44 of Set 5 | ub
# City not found. Skipping...
# Processing Record 45 of Set 5 | kpandu
# Processing Record 46 of Set 5 | galesong
# Processing Record 47 of Set 5 | kushiro
# Processing Record 48 of Set 5 | wagar
# Processing Record 49 of Set 5 | bonga
# Processing Record 50 of Set 5 | tessalit
# Processing Record 1 of Set 6 | arvika
# Processing Record 2 of Set 6 | fairbanks
# Processing Record 3 of Set 6 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 4 of Set 6 | worpswede
# Processing Record 5 of Set 6 | jalu
# Processing Record 6 of Set 6 | haines junction
# Processing Record 7 of Set 6 | srednekolymsk
# Processing Record 8 of Set 6 | octeville
# Processing Record 9 of Set 6 | juegang
# Processing Record 10 of Set 6 | jamestown
# Processing Record 11 of Set 6 | ouargaye
# Processing Record 12 of Set 6 | kerrobert
# Processing Record 13 of Set 6 | buala
# Processing Record 14 of Set 6 | gizo
# Processing Record 15 of Set 6 | sur
# Processing Record 16 of Set 6 | pakxan
# Processing Record 17 of Set 6 | chokurdakh
# Processing Record 18 of Set 6 | dongsheng
# Processing Record 19 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 20 of Set 6 | thunder bay
# Processing Record 21 of Set 6 | plavsk
# Processing Record 22 of Set 6 | inuvik
# Processing Record 23 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 6 | nanakuli
# Processing Record 25 of Set 6 | sao joao da barra
# Processing Record 26 of Set 6 | pangai
# Processing Record 27 of Set 6 | balkhash
# Processing Record 28 of Set 6 | almeirim
# Processing Record 29 of Set 6 | faanui
# Processing Record 30 of Set 6 | thanatpin
# Processing Record 31 of Set 6 | nouakchott
# Processing Record 32 of Set 6 | pozo colorado
# Processing Record 33 of Set 6 | salamiyah
# Processing Record 34 of Set 6 | goderich
# Processing Record 35 of Set 6 | airai
# Processing Record 36 of Set 6 | dingle
# Processing Record 37 of Set 6 | saint-pierre
# Processing Record 38 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 6 | talaya
# Processing Record 40 of Set 6 | puerto penasco
# Processing Record 41 of Set 6 | jaleswar
# Processing Record 42 of Set 6 | biak
# Processing Record 43 of Set 6 | brae
# Processing Record 44 of Set 6 | georgetown
# Processing Record 45 of Set 6 | longyearbyen
# Processing Record 46 of Set 6 | ardakan
# Processing Record 47 of Set 6 | kulhudhuffushi
# Processing Record 48 of Set 6 | marsaxlokk
# Processing Record 49 of Set 6 | jackson
# Processing Record 50 of Set 6 | mayumba
# Processing Record 1 of Set 7 | coquimbo
# Processing Record 2 of Set 7 | broken hill
# Processing Record 3 of Set 7 | ulladulla
# Processing Record 4 of Set 7 | lamar
# Processing Record 5 of Set 7 | gusinoye ozero
# Processing Record 6 of Set 7 | boca do acre
# Processing Record 7 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 8 of Set 7 | nichlaul
# Processing Record 9 of Set 7 | bathsheba
# Processing Record 10 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 7 | kumluca
# Processing Record 12 of Set 7 | tabou
# Processing Record 13 of Set 7 | amahai
# Processing Record 14 of Set 7 | kingaroy
# Processing Record 15 of Set 7 | teguldet
# Processing Record 16 of Set 7 | inhambane
# Processing Record 17 of Set 7 | abu samrah
# Processing Record 18 of Set 7 | tilichiki
# Processing Record 19 of Set 7 | beni
# Processing Record 20 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 7 | dubuque
# Processing Record 23 of Set 7 | benque viejo
# City not found. Skipping...
# Processing Record 24 of Set 7 | bundaberg
# Processing Record 25 of Set 7 | valparaiso
# Processing Record 26 of Set 7 | olafsvik
# Processing Record 27 of Set 7 | sobolevo
# Processing Record 28 of Set 7 | christchurch
# Processing Record 29 of Set 7 | sassandra
# Processing Record 30 of Set 7 | formosa do rio preto
# Processing Record 31 of Set 7 | starokostyantyniv
# Processing Record 32 of Set 7 | atlantic city
# Processing Record 33 of Set 7 | auch
# Processing Record 34 of Set 7 | the valley
# Processing Record 35 of Set 7 | storsteinnes
# Processing Record 36 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 7 | bandar-e anzali
# Processing Record 38 of Set 7 | nata
# Processing Record 39 of Set 7 | varna
# Processing Record 40 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 7 | polunochnoye
# Processing Record 42 of Set 7 | koboldo
# City not found. Skipping...
# Processing Record 43 of Set 7 | majene
# Processing Record 44 of Set 7 | altay
# Processing Record 45 of Set 7 | yar-sale
# Processing Record 46 of Set 7 | pangkalanbuun
# Processing Record 47 of Set 7 | beian
# Processing Record 48 of Set 7 | quatre cocos
# Processing Record 49 of Set 7 | pokhara
# Processing Record 50 of Set 7 | nha trang
# Processing Record 1 of Set 8 | honiara
# Processing Record 2 of Set 8 | olinda
# Processing Record 3 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 4 of Set 8 | los llanos de aridane
# Processing Record 5 of Set 8 | ormara
# Processing Record 6 of Set 8 | krasnoselkup
# Processing Record 7 of Set 8 | tual
# Processing Record 8 of Set 8 | merrill
# Processing Record 9 of Set 8 | kununurra
# Processing Record 10 of Set 8 | faya
# Processing Record 11 of Set 8 | terra nova
# Processing Record 12 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 8 | tahoua
# Processing Record 14 of Set 8 | leningradskiy
# Processing Record 15 of Set 8 | soufriere
# Processing Record 16 of Set 8 | pangody
# Processing Record 17 of Set 8 | zasheyek
# Processing Record 18 of Set 8 | ergani
# Processing Record 19 of Set 8 | sao jose da coroa grande
# Processing Record 20 of Set 8 | fort nelson
# Processing Record 21 of Set 8 | dalby
# Processing Record 22 of Set 8 | goldap
# Processing Record 23 of Set 8 | chongwe
# Processing Record 24 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 8 | huarmey
# Processing Record 26 of Set 8 | sibu
# Processing Record 27 of Set 8 | palmas bellas
# Processing Record 28 of Set 8 | nome
# Processing Record 29 of Set 8 | opuwo
# Processing Record 30 of Set 8 | zeya
# Processing Record 31 of Set 8 | belmonte
# Processing Record 32 of Set 8 | zhanaozen
# Processing Record 33 of Set 8 | kilimatinde
# Processing Record 34 of Set 8 | bustamante
# Processing Record 35 of Set 8 | japura
# Processing Record 36 of Set 8 | manicore
# Processing Record 37 of Set 8 | bengkulu
# Processing Record 38 of Set 8 | flinders
# Processing Record 39 of Set 8 | freetown
# Processing Record 40 of Set 8 | arlit
# Processing Record 41 of Set 8 | bilibino
# Processing Record 42 of Set 8 | ipswich
# Processing Record 43 of Set 8 | san luis
# Processing Record 44 of Set 8 | tyn nad vltavou
# Processing Record 45 of Set 8 | fangshan
# Processing Record 46 of Set 8 | tavda
# Processing Record 47 of Set 8 | riacho de santana
# Processing Record 48 of Set 8 | manaure
# Processing Record 49 of Set 8 | tashtagol
# Processing Record 50 of Set 8 | karabuk
# Processing Record 1 of Set 9 | rafsanjan
# Processing Record 2 of Set 9 | hokitika
# Processing Record 3 of Set 9 | college
# Processing Record 4 of Set 9 | badou
# Processing Record 5 of Set 9 | eureka
# Processing Record 6 of Set 9 | vao
# Processing Record 7 of Set 9 | pali
# Processing Record 8 of Set 9 | makat
# Processing Record 9 of Set 9 | saint anthony
# Processing Record 10 of Set 9 | carahue
# Processing Record 11 of Set 9 | niono
# Processing Record 12 of Set 9 | okakarara
# Processing Record 13 of Set 9 | tautira
# Processing Record 14 of Set 9 | rebrikha
# Processing Record 15 of Set 9 | hay river
# Processing Record 16 of Set 9 | huanuco
# Processing Record 17 of Set 9 | pacific grove
# Processing Record 18 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 9 | havoysund
# Processing Record 20 of Set 9 | basco
# Processing Record 21 of Set 9 | livingstonia
# Processing Record 22 of Set 9 | koumac
# Processing Record 23 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 9 | leh
# Processing Record 25 of Set 9 | henties bay
# Processing Record 26 of Set 9 | tolaga bay
# Processing Record 27 of Set 9 | lipin bor
# Processing Record 28 of Set 9 | rivadavia
# Processing Record 29 of Set 9 | port macquarie
# Processing Record 30 of Set 9 | cidreira
# Processing Record 31 of Set 9 | batemans bay
# Processing Record 32 of Set 9 | batagay-alyta
# Processing Record 33 of Set 9 | praya
# Processing Record 34 of Set 9 | aykhal
# Processing Record 35 of Set 9 | puerto escondido
# Processing Record 36 of Set 9 | palmer
# Processing Record 37 of Set 9 | hambantota
# Processing Record 38 of Set 9 | petatlan
# Processing Record 39 of Set 9 | jega
# Processing Record 40 of Set 9 | cap malheureux
# Processing Record 41 of Set 9 | quelimane
# Processing Record 42 of Set 9 | sao felix do xingu
# Processing Record 43 of Set 9 | alugan
# Processing Record 44 of Set 9 | sao filipe
# Processing Record 45 of Set 9 | muisne
# Processing Record 46 of Set 9 | innisfail
# Processing Record 47 of Set 9 | samarai
# Processing Record 48 of Set 9 | kathmandu
# Processing Record 49 of Set 9 | sarkand
# Processing Record 50 of Set 9 | san patricio
# Processing Record 1 of Set 10 | son la
# Processing Record 2 of Set 10 | pisco
# Processing Record 3 of Set 10 | makakilo city
# Processing Record 4 of Set 10 | merauke
# Processing Record 5 of Set 10 | khandyga
# Processing Record 6 of Set 10 | deputatskiy
# Processing Record 7 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 10 | arona
# Processing Record 9 of Set 10 | lazaro cardenas
# Processing Record 10 of Set 10 | yumen
# Processing Record 11 of Set 10 | tainan
# Processing Record 12 of Set 10 | lexington
# Processing Record 13 of Set 10 | grootfontein
# Processing Record 14 of Set 10 | damietta
# Processing Record 15 of Set 10 | upernavik
# Processing Record 16 of Set 10 | sumkino
# Processing Record 17 of Set 10 | solwezi
# Processing Record 18 of Set 10 | ipameri
# Processing Record 19 of Set 10 | calderitas
# Processing Record 20 of Set 10 | noumea
# Processing Record 21 of Set 10 | yantal
# Processing Record 22 of Set 10 | saint-augustin
# Processing Record 23 of Set 10 | payson
# Processing Record 24 of Set 10 | ligayan
# Processing Record 25 of Set 10 | port-cartier
# Processing Record 26 of Set 10 | neuquen
# Processing Record 27 of Set 10 | tromso
# Processing Record 28 of Set 10 | pangnirtung
# Processing Record 29 of Set 10 | springbok
# Processing Record 30 of Set 10 | buchanan
# Processing Record 31 of Set 10 | caronport
# Processing Record 32 of Set 10 | aswan
# Processing Record 33 of Set 10 | sereflikochisar
# Processing Record 34 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 35 of Set 10 | jinka
# Processing Record 36 of Set 10 | flin flon
# Processing Record 37 of Set 10 | gornopravdinsk
# Processing Record 38 of Set 10 | palana
# Processing Record 39 of Set 10 | uyuni
# Processing Record 40 of Set 10 | azamgarh
# Processing Record 41 of Set 10 | kargasok
# Processing Record 42 of Set 10 | bath
# Processing Record 43 of Set 10 | chapayeve
# Processing Record 44 of Set 10 | kisangani
# Processing Record 45 of Set 10 | pangoa
# Processing Record 46 of Set 10 | arman
# Processing Record 47 of Set 10 | kedrovka
# Processing Record 48 of Set 10 | fukue
# Processing Record 49 of Set 10 | rusape
# Processing Record 50 of Set 10 | farafangana
# Processing Record 1 of Set 11 | bara
# Processing Record 2 of Set 11 | duldurga
# Processing Record 3 of Set 11 | saalfeld
# Processing Record 4 of Set 11 | qostanay
# Processing Record 5 of Set 11 | viransehir
# Processing Record 6 of Set 11 | sosnovskiy
# City not found. Skipping...
# Processing Record 7 of Set 11 | zambezi
# Processing Record 8 of Set 11 | peleduy
# Processing Record 9 of Set 11 | lekoni
# Processing Record 10 of Set 11 | guajara-mirim
# City not found. Skipping...
# Processing Record 11 of Set 11 | mantua
# Processing Record 12 of Set 11 | mongo
# Processing Record 13 of Set 11 | sawakin
# Processing Record 14 of Set 11 | mezen
# Processing Record 15 of Set 11 | norrtalje
# Processing Record 16 of Set 11 | ust-ishim
# Processing Record 17 of Set 11 | maloy
# Processing Record 18 of Set 11 | axim
# Processing Record 19 of Set 11 | riverton
# Processing Record 20 of Set 11 | nador
# Processing Record 21 of Set 11 | labuhan
# Processing Record 22 of Set 11 | santa maria
# Processing Record 23 of Set 11 | acarau
# Processing Record 24 of Set 11 | sibolga
# Processing Record 25 of Set 11 | saint-francois
# Processing Record 26 of Set 11 | fernley
# Processing Record 27 of Set 11 | calbuco
# Processing Record 28 of Set 11 | port lincoln
# Processing Record 29 of Set 11 | aden
# Processing Record 30 of Set 11 | sao raimundo nonato
# Processing Record 31 of Set 11 | jabinyanah
# Processing Record 32 of Set 11 | bacolod
# Processing Record 33 of Set 11 | lagos
# Processing Record 34 of Set 11 | codrington
# Processing Record 35 of Set 11 | thiruvananthapuram
# Processing Record 36 of Set 11 | moengo
# Processing Record 37 of Set 11 | port hardy
# Processing Record 38 of Set 11 | muroto
# Processing Record 39 of Set 11 | okhotsk
# Processing Record 40 of Set 11 | tomatlan
# Processing Record 41 of Set 11 | zhezkazgan
# Processing Record 42 of Set 11 | yakeshi
# Processing Record 43 of Set 11 | manokwari
# Processing Record 44 of Set 11 | northam
# Processing Record 45 of Set 11 | isangel
# Processing Record 46 of Set 11 | alenquer
# Processing Record 47 of Set 11 | ban nahin
# Processing Record 48 of Set 11 | minot
# Processing Record 49 of Set 11 | beidao
# Processing Record 50 of Set 11 | cairns
# Processing Record 1 of Set 12 | villamontes
# Processing Record 2 of Set 12 | neftcala
# Processing Record 3 of Set 12 | plouzane
# Processing Record 4 of Set 12 | mawlaik
# Processing Record 5 of Set 12 | chicama
# Processing Record 6 of Set 12 | luderitz
# Processing Record 7 of Set 12 | agadir
# Processing Record 8 of Set 12 | bom jesus
# Processing Record 9 of Set 12 | ixtapa
# Processing Record 10 of Set 12 | diplo
# Processing Record 11 of Set 12 | ouesso
# Processing Record 12 of Set 12 | dickinson
# Processing Record 13 of Set 12 | yinchuan
# Processing Record 14 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 12 | santo domingo
# Processing Record 16 of Set 12 | zhaoyuan
# Processing Record 17 of Set 12 | barcelos
# Processing Record 18 of Set 12 | bekovo
# Processing Record 19 of Set 12 | elko
# Processing Record 20 of Set 12 | shemgang
# Processing Record 21 of Set 12 | cayenne
# Processing Record 22 of Set 12 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 23 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 12 | fallon
# Processing Record 25 of Set 12 | mpanda
# Processing Record 26 of Set 12 | ca mau
# Processing Record 27 of Set 12 | ratnagiri
# Processing Record 28 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 12 | lemesos
# City not found. Skipping...
# Processing Record 30 of Set 12 | clarence town
# Processing Record 31 of Set 12 | san jose
# Processing Record 32 of Set 12 | filingue
# Processing Record 33 of Set 12 | ambanja
# Processing Record 34 of Set 12 | nemuro
# Processing Record 35 of Set 12 | hun
# Processing Record 36 of Set 12 | mackay
# Processing Record 37 of Set 12 | bubaque
# Processing Record 38 of Set 12 | rawlins
# Processing Record 39 of Set 12 | terrace
# Processing Record 40 of Set 12 | jijiga
# Processing Record 41 of Set 12 | iqaluit
# Processing Record 42 of Set 12 | jawhar
# Processing Record 43 of Set 12 | molepolole
# Processing Record 44 of Set 12 | port shepstone
# Processing Record 45 of Set 12 | mayo
# Processing Record 46 of Set 12 | omsukchan
# Processing Record 47 of Set 12 | camargo
# Processing Record 48 of Set 12 | sagu
# Processing Record 49 of Set 12 | maracaju
# Processing Record 50 of Set 12 | karpogory
# Processing Record 1 of Set 13 | varkaus
# Processing Record 2 of Set 13 | kodinsk
# Processing Record 3 of Set 13 | mina
# Processing Record 4 of Set 13 | amarpur
# Processing Record 5 of Set 13 | alice springs
# Processing Record 6 of Set 13 | havelock
# Processing Record 7 of Set 13 | turbat
# Processing Record 8 of Set 13 | arco
# Processing Record 9 of Set 13 | karratha
# Processing Record 10 of Set 13 | alghero
# Processing Record 11 of Set 13 | thinadhoo
# Processing Record 12 of Set 13 | san andres
# Processing Record 13 of Set 13 | shkotovo-26
# City not found. Skipping...
# Processing Record 14 of Set 13 | bulgan
# Processing Record 15 of Set 13 | aksu
# Processing Record 16 of Set 13 | augustdorf
# Processing Record 17 of Set 13 | zatoka
# Processing Record 18 of Set 13 | bahia blanca
# Processing Record 19 of Set 13 | nenjiang
# Processing Record 20 of Set 13 | port-gentil
# Processing Record 21 of Set 13 | kasongo-lunda
# Processing Record 22 of Set 13 | cruzeiro do sul
# Processing Record 23 of Set 13 | hualmay
# Processing Record 24 of Set 13 | pitimbu
# Processing Record 25 of Set 13 | vardo
# Processing Record 26 of Set 13 | ishigaki
# Processing Record 27 of Set 13 | roma
# Processing Record 28 of Set 13 | tselinnoye
# Processing Record 29 of Set 13 | porto velho
# Processing Record 30 of Set 13 | moose factory
# Processing Record 31 of Set 13 | yerbogachen
# Processing Record 32 of Set 13 | inverness
# Processing Record 33 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 34 of Set 13 | ndola
# Processing Record 35 of Set 13 | manisa
# Processing Record 36 of Set 13 | mala
# Processing Record 37 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 38 of Set 13 | tabuk
# Processing Record 39 of Set 13 | kysyl-syr
# Processing Record 40 of Set 13 | urengoy
# Processing Record 41 of Set 13 | severnyy
# Processing Record 42 of Set 13 | ulaanbaatar
# Processing Record 43 of Set 13 | canico
# Processing Record 44 of Set 13 | plettenberg bay
# Processing Record 45 of Set 13 | rorvik
# Processing Record 46 of Set 13 | trojes
# Processing Record 47 of Set 13 | naze
# Processing Record 48 of Set 13 | puerto del rosario
# Processing Record 49 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 13 | gryazi
# Processing Record 1 of Set 14 | san matias
# Processing Record 2 of Set 14 | katobu
# Processing Record 3 of Set 14 | aksha
# Processing Record 4 of Set 14 | poum
# Processing Record 5 of Set 14 | husavik
# Processing Record 6 of Set 14 | chiredzi
# Processing Record 7 of Set 14 | rio claro
# Processing Record 8 of Set 14 | itarema
# Processing Record 9 of Set 14 | finschhafen
# Processing Record 10 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 14 | dubrovnik
# Processing Record 12 of Set 14 | havre-saint-pierre
# Processing Record 13 of Set 14 | camacha
# Processing Record 14 of Set 14 | mbuji-mayi
# Processing Record 15 of Set 14 | burica
# City not found. Skipping...
# Processing Record 16 of Set 14 | kindberg
# Processing Record 17 of Set 14 | lewistown
# Processing Record 18 of Set 14 | dakar
# Processing Record 19 of Set 14 | upata
# Processing Record 20 of Set 14 | watrous
# Processing Record 21 of Set 14 | lima
# Processing Record 22 of Set 14 | cuxhaven
# Processing Record 23 of Set 14 | ler
# Processing Record 24 of Set 14 | destin
# Processing Record 25 of Set 14 | linxia
# Processing Record 26 of Set 14 | kologriv
# Processing Record 27 of Set 14 | sioux lookout
# Processing Record 28 of Set 14 | barranca
# Processing Record 29 of Set 14 | nhulunbuy
# Processing Record 30 of Set 14 | sijunjung
# Processing Record 31 of Set 14 | killybegs
# Processing Record 32 of Set 14 | makokou
# Processing Record 33 of Set 14 | gambo
# Processing Record 34 of Set 14 | abdanan
# Processing Record 35 of Set 14 | surt
# Processing Record 36 of Set 14 | ekibastuz
# Processing Record 37 of Set 14 | barguzin
# Processing Record 38 of Set 14 | samarinda
# Processing Record 39 of Set 14 | eyemouth
# Processing Record 40 of Set 14 | krivosheino
# Processing Record 41 of Set 14 | abu dhabi
# Processing Record 42 of Set 14 | mwinilunga
# Processing Record 43 of Set 14 | pimentel
# Processing Record 44 of Set 14 | magistralnyy
# Processing Record 45 of Set 14 | nusaybin
# Processing Record 46 of Set 14 | solnechnyy
# Processing Record 47 of Set 14 | hofn
# Processing Record 48 of Set 14 | namatanai
# Processing Record 49 of Set 14 | ferrol
# Processing Record 50 of Set 14 | marzuq
# Processing Record 1 of Set 15 | araouane
# Processing Record 2 of Set 15 | dukat
# Processing Record 3 of Set 15 | ocos
# Processing Record 4 of Set 15 | ambatondrazaka
# Processing Record 5 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 15 | ambon
# Processing Record 7 of Set 15 | tutoia
# Processing Record 8 of Set 15 | paamiut
# Processing Record 9 of Set 15 | atherton
# Processing Record 10 of Set 15 | rena
# Processing Record 11 of Set 15 | kungurtug
# Processing Record 12 of Set 15 | oga
# Processing Record 13 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 15 | elek
# Processing Record 15 of Set 15 | guayaramerin
# Processing Record 16 of Set 15 | alindao
# Processing Record 17 of Set 15 | nokaneng
# Processing Record 18 of Set 15 | anloga
# Processing Record 19 of Set 15 | okha
# Processing Record 20 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 21 of Set 15 | salinas
# Processing Record 22 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 23 of Set 15 | san juan
# Processing Record 24 of Set 15 | virginia beach
# Processing Record 25 of Set 15 | vestmannaeyjar
# Processing Record 26 of Set 15 | boksitogorsk
# Processing Record 27 of Set 15 | boyolangu
# Processing Record 28 of Set 15 | teknaf
# Processing Record 29 of Set 15 | coxim
# Processing Record 30 of Set 15 | nouadhibou
# Processing Record 31 of Set 15 | kendari
# Processing Record 32 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 33 of Set 15 | xghajra
# City not found. Skipping...
# Processing Record 34 of Set 15 | san carlos
# Processing Record 35 of Set 15 | teseney
# Processing Record 36 of Set 15 | victor harbor
# Processing Record 37 of Set 15 | suao
# City not found. Skipping...
# Processing Record 38 of Set 15 | szentlorinc
# Processing Record 39 of Set 15 | payakumbuh
# Processing Record 40 of Set 15 | nuuk
# Processing Record 41 of Set 15 | devonport
# Processing Record 42 of Set 15 | bumba
# Processing Record 43 of Set 15 | kinablangan
# Processing Record 44 of Set 15 | tagusao
# Processing Record 45 of Set 15 | mahenge
# Processing Record 46 of Set 15 | dubbo
# Processing Record 47 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 48 of Set 15 | gzhatsk
# City not found. Skipping...
# Processing Record 49 of Set 15 | canutama
# Processing Record 50 of Set 15 | muros
# Processing Record 1 of Set 16 | waipawa
# Processing Record 2 of Set 16 | mutum
# Processing Record 3 of Set 16 | taltal
# Processing Record 4 of Set 16 | itoman
# Processing Record 5 of Set 16 | rurrenabaque
# Processing Record 6 of Set 16 | beloha
# Processing Record 7 of Set 16 | berlevag
# Processing Record 8 of Set 16 | mecca
# Processing Record 9 of Set 16 | mangochi
# Processing Record 10 of Set 16 | gat
# Processing Record 11 of Set 16 | birao
# Processing Record 12 of Set 16 | port hedland
# Processing Record 13 of Set 16 | salinopolis
# Processing Record 14 of Set 16 | gazanjyk
# Processing Record 15 of Set 16 | aguilas
# Processing Record 16 of Set 16 | sataua
# City not found. Skipping...
# Processing Record 17 of Set 16 | visby
# Processing Record 18 of Set 16 | saint-joseph
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  New Norfolk      AU -42.7826  147.0587     71.10        76         100
# 1       Hobart      AU -42.8794  147.3294     71.46        60          75
# 2   Nikolskoye      RU  59.7035   30.7861     21.40        95         100
# 3      Ushuaia      AR -54.8000  -68.3000     40.46        97          95
# 4    Busselton      AU -33.6500  115.3333     77.09        37          45
#
#    Wind Speed Current Description
# 0        4.79     overcast clouds
# 1       10.36       broken clouds
# 2        6.40                snow
# 3        3.04          light rain
# 4       17.47    scattered clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
